# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd # Read/write data

sd_df_1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ECE697/Project/Synthetic Data/synthetic-dataset-001.csv") # read synthetic dataset
sd_df_2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ECE697/Project/Synthetic Data/synthetic-dataset-002.csv") # read synthetic dataset
sd_df_3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ECE697/Project/Synthetic Data/synthetic-dataset-003.csv") # read synthetic dataset

synth_data = pd.concat([sd_df_1, sd_df_2, sd_df_3]) # concatenate synthetic datasets

# %%
len(synth_data.index) # double check size of merged dataset
# Out:
# 3000000

# %%
synth_data.to_csv("/content/drive/MyDrive/Colab Notebooks/ECE697/Project/Synthetic Data/synthetic-data-merged.csv", encoding='utf-8') # write merged dataset to csv
